# %% [markdown]
# # this is a policy strategy
# 	data set policy

# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/policy_sequences_by_comb_enriched.csv')
# Out:
# /tmp/ipykernel_26905/2229576720.py:1: DtypeWarning: Columns (23,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/policy_sequences_by_comb_enriched.csv')

# %%
df
# Out:
#           Policy_Sequence        Unnamed: 1  Q  Tp  Tnp    p    W1  W2  \
# 0      [0, 2, 2, 2, 2, 2]        30.10.1110  5   1    3  0.1     1   1
# 1      [0, 2, 2, 2, 2, 2]      30.10.1110.1  5   1    3  0.1     1   1
# 2      [0, 2, 2, 2, 2, 2]      30.10.1110.2  5   1    3  0.1     1   1
# 3      [0, 2, 2, 2, 2, 2]      30.10.1110.3  5   1    3  0.1     1   1
# 4      [0, 2, 2, 2, 2, 2]      30.10.1110.4  5   1    3  0.1     1   1
# ...                   ...               ... ..  ..  ...  ...   ...  ..
# 21370  [0, 0, 0, 0, 0, 2]  150.90.3110000.5  5   1   15  0.9  1000   1
# 21371  [0, 0, 0, 0, 0, 2]  150.90.3110000.6  5   1   15  0.9  1000   1
# 21372  [0, 0, 0, 0, 0, 2]  150.90.3110000.7  5   1   15  0.9  1000   1
# 21373  [0, 0, 0, 0, 0, 2]  150.90.3110000.8  5   1   15  0.9  1000   1
# 21374  [0, 0, 0, 0, 0, 2]  150.90.3110000.9  5   1   15  0.9  1000   1
#
#        arrival_rate     gamma  ... arrival_rate.1   gamma.1 Unnamed: 34  \
# ...

# %%
df.head()
# Out:
#       Policy_Sequence    Unnamed: 1  Q  Tp  Tnp    p  W1  W2  arrival_rate  \
# 0  [0, 2, 2, 2, 2, 2]    30.10.1110  5   1    3  0.1   1   1           0.1
# 1  [0, 2, 2, 2, 2, 2]  30.10.1110.1  5   1    3  0.1   1   1           0.1
# 2  [0, 2, 2, 2, 2, 2]  30.10.1110.2  5   1    3  0.1   1   1           0.1
# 3  [0, 2, 2, 2, 2, 2]  30.10.1110.3  5   1    3  0.1   1   1           0.1
# 4  [0, 2, 2, 2, 2, 2]  30.10.1110.4  5   1    3  0.1   1   1           0.1
#
#       gamma  ... arrival_rate.1   gamma.1 Unnamed: 34  Unnamed: 35 Tnp.3  \
# 0  0.010000  ...          0.100  0.010000         NaN          NaN   3.0
# 1  0.118889  ...          0.225  0.118889         NaN          NaN   6.0
# 2  0.227778  ...          0.350  0.227778         NaN          NaN   NaN
# 3  0.336667  ...          0.475  0.336667         NaN          NaN   NaN
# 4  0.445556  ...          0.600  0.445556         NaN          NaN   NaN
#
#         p.3  Lambda.1  T.1   W1.3   Gamma.1
# ...

# %%
print(f"this is a shape data {df.shape}")
# Out:
# this is a shape data (21375, 42)

# %%
print(f"this is a columns data {df.columns}")
# Out:
# this is a columns data Index(['Policy_Sequence', 'Unnamed: 1', 'Q', 'Tp', 'Tnp', 'p', 'W1', 'W2',
#        'arrival_rate', 'gamma', 'Policy_Type', 'Switch_Index', 'Full Policy',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Tnp.1', 'p.1', 'Lambda',
#        'T', 'W1.1', 'Gamma', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25', 'Unnamed: 26', 'Tp.1', 'Tnp.2', 'p.2', 'W1.2', 'W2.1',
#        'arrival_rate.1', 'gamma.1', 'Unnamed: 34', 'Unnamed: 35', 'Tnp.3',
#        'p.3', 'Lambda.1', 'T.1', 'W1.3', 'Gamma.1'],
#       dtype='object')

# %%
df.describe()
# Out:
#              Q       Tp           Tnp             p            W1       W2  \
# count  21375.0  21375.0  21375.000000  21375.000000  21375.000000  21375.0
# mean       5.0      1.0      8.221333      0.499753    500.793404      1.0
# std        0.0      0.0      4.045520      0.255321    318.711199      0.0
# min        5.0      1.0      3.000000      0.100000      1.000000      1.0
# 25%        5.0      1.0      6.000000      0.277778    223.000000      1.0
# 50%        5.0      1.0      9.000000      0.544444    556.000000      1.0
# 75%        5.0      1.0     12.000000      0.722222    778.000000      1.0
# max        5.0      1.0     15.000000      0.900000   1000.000000      1.0
#
#        arrival_rate         gamma  Switch_Index  Unnamed: 13  ...  \
# count  21375.000000  21375.000000    121.000000          0.0  ...
# mean       0.316655      0.499722      3.793388          NaN  ...
# std        0.167718      0.312699      0.805371          NaN  ...
# ...

# %%
pd.DataFrame(df)
# Out:
#           Policy_Sequence        Unnamed: 1  Q  Tp  Tnp    p    W1  W2  \
# 0      [0, 2, 2, 2, 2, 2]        30.10.1110  5   1    3  0.1     1   1
# 1      [0, 2, 2, 2, 2, 2]      30.10.1110.1  5   1    3  0.1     1   1
# 2      [0, 2, 2, 2, 2, 2]      30.10.1110.2  5   1    3  0.1     1   1
# 3      [0, 2, 2, 2, 2, 2]      30.10.1110.3  5   1    3  0.1     1   1
# 4      [0, 2, 2, 2, 2, 2]      30.10.1110.4  5   1    3  0.1     1   1
# ...                   ...               ... ..  ..  ...  ...   ...  ..
# 21370  [0, 0, 0, 0, 0, 2]  150.90.3110000.5  5   1   15  0.9  1000   1
# 21371  [0, 0, 0, 0, 0, 2]  150.90.3110000.6  5   1   15  0.9  1000   1
# 21372  [0, 0, 0, 0, 0, 2]  150.90.3110000.7  5   1   15  0.9  1000   1
# 21373  [0, 0, 0, 0, 0, 2]  150.90.3110000.8  5   1   15  0.9  1000   1
# 21374  [0, 0, 0, 0, 0, 2]  150.90.3110000.9  5   1   15  0.9  1000   1
#
#        arrival_rate     gamma  ... arrival_rate.1   gamma.1 Unnamed: 34  \
# ...

# %%
df.isna().any()
# Out:
# Policy_Sequence    False
# Unnamed: 1         False
# Q                  False
# Tp                 False
# Tnp                False
# p                  False
# W1                 False
# W2                 False
# arrival_rate       False
# gamma              False
# Policy_Type        False
# Switch_Index        True
# Full Policy        False
# Unnamed: 13         True
# Unnamed: 14        False
# Unnamed: 15         True
# Tnp.1               True
# p.1                 True
# Lambda              True
# T                   True
# W1.1                True
# Gamma               True
# Unnamed: 22         True
# Unnamed: 23         True
# Unnamed: 24         True
# Unnamed: 25         True
# Unnamed: 26         True
# Tp.1                True
# Tnp.2               True
# p.2                 True
# W1.2                True
# W2.1                True
# arrival_rate.1      True
# gamma.1             True
# Unnamed: 34         True
# Unnamed: 35         True
# Tnp.3               True
# ...

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.head()
# Out:
#       Policy_Sequence    Unnamed: 1  Q  Tp  Tnp    p  W1  W2  arrival_rate  \
# 0  [0, 2, 2, 2, 2, 2]    30.10.1110  5   1    3  0.1   1   1           0.1
# 1  [0, 2, 2, 2, 2, 2]  30.10.1110.1  5   1    3  0.1   1   1           0.1
# 2  [0, 2, 2, 2, 2, 2]  30.10.1110.2  5   1    3  0.1   1   1           0.1
# 3  [0, 2, 2, 2, 2, 2]  30.10.1110.3  5   1    3  0.1   1   1           0.1
# 4  [0, 2, 2, 2, 2, 2]  30.10.1110.4  5   1    3  0.1   1   1           0.1
#
#       gamma  ... arrival_rate.1   gamma.1 Unnamed: 34  Unnamed: 35 Tnp.3  \
# 0  0.010000  ...          0.100  0.010000         NaN          NaN   3.0
# 1  0.118889  ...          0.225  0.118889         NaN          NaN   6.0
# 2  0.227778  ...          0.350  0.227778         NaN          NaN   4.5
# 3  0.336667  ...          0.475  0.336667         NaN          NaN   4.5
# 4  0.445556  ...          0.600  0.445556         NaN          NaN   4.5
#
#         p.3  Lambda.1  T.1   W1.3   Gamma.1
# ...

# %%
df.corr
# Out:
# <bound method DataFrame.corr of           Policy_Sequence        Unnamed: 1  Q  Tp  Tnp    p    W1  W2  \
# 0      [0, 2, 2, 2, 2, 2]        30.10.1110  5   1    3  0.1     1   1
# 1      [0, 2, 2, 2, 2, 2]      30.10.1110.1  5   1    3  0.1     1   1
# 2      [0, 2, 2, 2, 2, 2]      30.10.1110.2  5   1    3  0.1     1   1
# 3      [0, 2, 2, 2, 2, 2]      30.10.1110.3  5   1    3  0.1     1   1
# 4      [0, 2, 2, 2, 2, 2]      30.10.1110.4  5   1    3  0.1     1   1
# ...                   ...               ... ..  ..  ...  ...   ...  ..
# 21370  [0, 0, 0, 0, 0, 2]  150.90.3110000.5  5   1   15  0.9  1000   1
# 21371  [0, 0, 0, 0, 0, 2]  150.90.3110000.6  5   1   15  0.9  1000   1
# 21372  [0, 0, 0, 0, 0, 2]  150.90.3110000.7  5   1   15  0.9  1000   1
# 21373  [0, 0, 0, 0, 0, 2]  150.90.3110000.8  5   1   15  0.9  1000   1
# 21374  [0, 0, 0, 0, 0, 2]  150.90.3110000.9  5   1   15  0.9  1000   1
#
#        arrival_rate     gamma  ... arrival_rate.1   gamma.1 Unnamed: 34  \
# ...
